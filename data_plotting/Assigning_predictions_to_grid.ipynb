# %%
### This notebook creates assigns the predictions to the particular tiles. 

import pandas as pd
import numpy as np

# %%
atr = pd.read_csv("/media/deepank/086C617F6C616880/extra_space/vhr_clip_177x177/vhr_2/atr_tab_2.csv", index_col= None)
atr.head()
# Out:
#               location  Unnamed: 1
# 0      dir_001/0_0.tif         NaN
# 1  dir_001/0_10089.tif         NaN
# 2  dir_001/0_10266.tif         NaN
# 3  dir_001/0_10443.tif         NaN
# 4  dir_001/0_10620.tif         NaN

# %%
print(atr.columns[1])
# Out:
# Unnamed: 1

# %%
predictions = np.load("/media/deepank/086C617F6C616880/extra_space/vhr_clip_177x177/mum2_map_prep_pleiades_predictions.npy")
grid_nos = np.load("/media/deepank/086C617F6C616880/extra_space/vhr_clip_177x177/mum2_map_prep_pleiades_lb.npy")

# %%
print(predictions.shape,grid_nos.shape)
# Out:
# (89631,) (89631,)

# %%
print(predictions[0],grid_nos[0])
# Out:
# 3 0_0

# %%
for each, i  in zip(atr["location"],range(len(atr))):
    each = each.split(".")[0]
    each = each.split("/")[-1]
    
    for grids, preds in zip(grid_nos,predictions):
        
        if each == grids:
            atr.set_value(i, "Unnamed: 1", preds)
            print("yes")
# Out:
# /home/deepank/anaconda3/envs/tensorflow/lib/python3.6/site-packages/ipykernel_launcher.py:8: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# ...

# %%
atr.head()
# Out:
#               location  Unnamed: 1
# 0      dir_001/0_0.tif         3.0
# 1  dir_001/0_10089.tif         3.0
# 2  dir_001/0_10266.tif         3.0
# 3  dir_001/0_10443.tif         3.0
# 4  dir_001/0_10620.tif         3.0

# %%
atr.head(50)
# Out:
#                location  Unnamed: 1
# 0       dir_001/0_0.tif         3.0
# 1   dir_001/0_10089.tif         3.0
# 2   dir_001/0_10266.tif         3.0
# 3   dir_001/0_10443.tif         3.0
# 4   dir_001/0_10620.tif         3.0
# 5    dir_001/0_1062.tif         3.0
# 6   dir_001/0_10797.tif         3.0
# 7   dir_001/0_10974.tif         3.0
# 8   dir_001/0_11151.tif         3.0
# 9   dir_001/0_11328.tif         3.0
# 10  dir_001/0_11505.tif         3.0
# 11  dir_001/0_11682.tif         3.0
# 12  dir_001/0_11859.tif         3.0
# 13  dir_001/0_12036.tif         3.0
# 14  dir_001/0_12213.tif         3.0
# 15  dir_001/0_12390.tif         3.0
# 16   dir_001/0_1239.tif         3.0
# 17  dir_001/0_12567.tif         3.0
# 18  dir_001/0_12744.tif         3.0
# 19  dir_001/0_12921.tif         3.0
# 20  dir_001/0_13098.tif         3.0
# 21  dir_001/0_13275.tif         3.0
# 22  dir_001/0_13452.tif         3.0
# 23  dir_001/0_13629.tif         3.0
# 24  dir_001/0_13806.tif         3.0
# ...

# %%
atr.to_csv("/media/deepank/086C617F6C616880/extra_space/vhr_clip_177x177/attached_predictions_mum2_pleiades.csv") ###here 1 is 2
